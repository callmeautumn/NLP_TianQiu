# %% [markdown]
# # Week 3: Building a stemmer and set of stop words
#
# In this weeks notebook we are going to build a simple stemmer and a set of stop words to use for our nursery rhymes dataset.
#
# We will be using bag of words again to represent our nursery rhymes, though this time we will be using the [CountVectorizer class](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) from the Python library [sci-kit learn](https://scikit-learn.org/stable/index.html).
#
# First lets do some imports:

# %%
import os
import re
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# This code cell defines a simple stemmer using [regex](https://www.w3schools.com/python/python_regex.asp). The code that defines the rules of the stemmer is commented out so it does not initially do anything, but we will come back to this later in the tasks, when we start building our stemmer.
#
# The first rule `(r's$', '')` looks to find the character `s` at the end of a word (which we define with `$`) and replaces it with an empty string `''`. When we uncomment this then any word with an `s` at the end with have that letter removed. The goal of this is to make words that are plural into  [singular nouns](https://www.ef.com/wwen/english-resources/english-grammar/singular-and-plural-nouns/).
#
# For now leave this as it is and run this cell, we will come back to this cell when we start to build our stemmer.
#
# <a id='stemmer'></a>

# %%
def simple_stemmer(word):
    # Define a list of stemming rules as tuples (pattern, replacement)
    stemming_rules = [
    # Uncomment the line below and add more rules when you come to Task 2
        # (r's\b', ''),    
    ]
    
    # Apply each rule to the word
    for pattern, replacement in stemming_rules:
        word = re.sub(pattern, replacement, word)
    
    return word

# %% [markdown]
# This fuction will go through every text file in a folder and load the contents of the file to the list `document_texts` and the name of the file to the list `documents_labels`. As you can see before it puts the text into the `documents_text` list, it first passes all of the words through the `simple_stemmer` function that we have just defined:

# %%
def load_text_documents(folder_path):
    # Make empty arrays for documents and file names
    document_texts = []
    document_labels = []

    # Find the files in the directory
    for root, _, files in os.walk(folder_path):
        
        # Go through each file 
        for file in files:
            
            # If it is a text file, read it and add it to the list of docuemnts
            # along with the filename (minus the extension)
            if file.endswith(".txt"):
                with open(os.path.join(root, file), 'r', encoding='utf-8') as f:
                    text = f.read()
                
                # Apply stemming to each word in the nursery rhyme
                stemmed_text = " ".join([simple_stemmer(word) for word in text.split()])
                document_texts.append(stemmed_text)
                document_labels.append(os.path.basename(file[:-4]))
    
    # Return list of full nursery rhymes and list of the names of each file
    return document_texts, document_labels

# %% [markdown]
# Now lets load in our dataset of all of our nursery rhymes, here our path starts with `..`, which tells Python to move up one file level to find the folder `data` which then contains the folder `nursery-rhymes` which contains our dataset of text files.

# %%
folder_path = "../data/nursery-rhymes"
document_texts, document_labels = load_text_documents(folder_path)
print(f'loaded {len(document_labels)} documents')
# Out:
# loaded 298 documents

# %% [markdown]
# Lets print out the name and contents of the first file we have loaded to see it is working correctly:

# %%
print(f'The first document is {document_labels[0]}, which goes:')
print(document_texts[0])
# Out:
# The first document is five-little-ducks, which goes:
# Five Little Ducks went out one day, over the hills and far away. Mother Duck said, “Quack, Quack, Quack, Quack,” but only four little ducks came back. Four little ducks went out one day, over the hills and far away Mother Duck said, “Quack, Quack, Quack, Quack,” but only three little ducks came back. (Repeat counting down to “but no little ducks came back.”) Sad mother duck went out one day, over the hills and far away Mother Duck said, “Quack, Quack, Quack, Quack,” and five little ducks came back.

# %% [markdown]
# Now lets define our set of stop words, these are words that we will remove from nursery rhymes that don't tell us anything meaningful about the contents of each individual rhyme. Often these are the most commonly used words like `and`, `it` and many others.
#
# Depending on what we are doing there may also be other stop words that we need to add that are specific to our dataset. To figure out what these are we need to have a good understanding of what is in the dataset to begin with.
#
# Here we are defining our set of stop words manually as a list of words. We will be coming back to this cell in the task to expand our list of stop words.
#
# <a id='stop-words'></a>

# %%
stop_words = ['and', 'it']

# %% [markdown]
# Now lets create our bag of words representation of our dataset. This time we will be looking at all of the words in the dataset, not just each individual file. We do this so we can make comparisons between the nursery rhymes (aka our documents).
#
# We will have a table (aka matrix) that is 299 in length (the number of nursery rhymes in our dataset) by the number of words in our dataset. When you start working on the task you will notice that the number of words will change when you start adding more stop words an rules to the stemmer.

# %%
vectorizer = CountVectorizer(stop_words=stop_words)
bag_of_words = vectorizer.fit_transform(document_texts)
print(f'Our bag of words is a matrix of the shape and size {bag_of_words.shape}')
# Out:
# Our bag of words is a matrix of the shape and size (298, 3416)

# %% [markdown]
# If we look at  our bag_or_words representation we we can see that it is a big table showing the counts of each word with each nursery rhyme. You will notice that for many of these entries they are 0. As we have a large variety of words across our dataset, but each nursery rhyme only contains a limited vocabulary.

# %%
bow_df = pd.DataFrame(bag_of_words.toarray(), columns=vectorizer.get_feature_names_out(), index=document_labels)
bow_df
# Out:
#                                15  1784  1812  3x  4th  aaples  abcs  abhors  \
# five-little-ducks               0     0     0   0    0       0     0       0
# old-mother-hubbard              0     0     0   0    0       0     0       0
# hey-diddle-diddle               0     0     0   0    0       0     0       0
# i-love-little-pussy             0     0     0   0    0       0     0       0
# skip-to-my-loo                  0     0     0   0    0       0     0       0
# ...                            ..   ...   ...  ..  ...     ...   ...     ...
# splash-splash                   0     0     0   0    0       0     0       0
# five-little-speckled-frogs      0     0     0   0    0       0     0       0
# here-i-am-little-jumping-joan   0     0     0   0    0       0     0       0
# twinkle-twinkle-little-star     0     0     0   0    0       0     0       0
# handy-spandy-jack-a-dandy       0     0     0   0    0       0     0       0
#
#                                aboard  about  ...  yours  yourself  youth  \
# five-little-ducks                   0      0  ...      0         0      0
# old-mother-hubbard                  0      0  ...      0         0      0
# hey-diddle-diddle                   0      0  ...      0         0      0
# i-love-little-pussy                 0      0  ...      0         0      0
# skip-to-my-loo                      0      0  ...      0         0      0
# ...                               ...    ...  ...    ...       ...    ...
# splash-splash                       0      0  ...      0         0      0
# five-little-speckled-frogs          0      0  ...      0         0      0
# here-i-am-little-jumping-joan       0      0  ...      0         0      0
# twinkle-twinkle-little-star         0      0  ...      0         0      0
# handy-spandy-jack-a-dandy           0      0  ...      0         0      0
#
#                                yum  yummy  zany  zee  zero  zoo  zoom
# five-little-ducks                0      0     0    0     0    0     0
# old-mother-hubbard               0      0     0    0     0    0     0
# hey-diddle-diddle                0      0     0    0     0    0     0
# i-love-little-pussy              0      0     0    0     0    0     0
# skip-to-my-loo                   0      0     0    0     0    0     0
# ...                            ...    ...   ...  ...   ...  ...   ...
# splash-splash                    0      0     0    0     0    0     0
# five-little-speckled-frogs      10      0     0    0     0    0     0
# here-i-am-little-jumping-joan    0      0     0    0     0    0     0
# twinkle-twinkle-little-star      0      0     0    0     0    0     0
# handy-spandy-jack-a-dandy        0      0     0    0     0    0     0
#
# [298 rows x 3416 columns]

# %% [markdown]
# If we want to see all of our words we can print them with the following code:
#
#
# <a id='all-words'></a>

# %%
np.set_printoptions(threshold = np.inf)
print(vectorizer.get_feature_names_out())
# Out:
# ['15' '1784' '1812' '3x' '4th' 'aaples' 'abcs' 'abhors' 'aboard' 'about'
#  'above' 'accidentally' 'across' 'adde' 'added' 'additional' 'adieu'
#  'adore' 'adored' 'adorned' 'afar' 'afeard' 'aff' 'afford' 'afore'
#  'afraid' 'after' 'afternoon' 'again' 'against' 'age' 'ago' 'agreed' 'ah'
#  'ahead' 'aiken' 'ain' 'air' 'airn' 'al' 'alabama' 'alas' 'alaska'
#  'aldgate' 'ale' 'alehouse' 'alice' 'alive' 'all' 'alleluia' 'alligator'
#  'allí' 'almost' 'alone' 'along' 'already' 'alternate' 'alternatively'
#  'always' 'am' 'amazing' 'among' 'amor' 'ampersand' 'an' 'ancient' 'anew'
#  'angel' 'angelic' 'angels' 'animal' 'ankle' 'ann' 'ano' 'another'
#  'answer' 'ant' 'anthems' 'ants' 'anunciando' 'any' 'anymore' 'anyone'
#  'anything' 'apart' 'appear' 'appearing' 'appetite' 'apple' 'apples'
#  'april' 'aprill' 'aprons' 'are' 'arkan' 'arkansas' 'arm' 'arms' 'around'
#  'arrow' 'arthur' 'as' 'ask' 'asked' 'asking' 'asks' 'asleep' 'ass'
#  'astros' 'at' 'ate' 'attention' 'attitude' 'autumn' 'avenue' 'avignon'
#  'avè' 'away' 'awful' 'awfully' 'awhile' 'awoke' 'axe' 'axes' 'ay' 'aye'
#  'baa' 'babe' 'baby' 'babylon' 'back' 'backey' 'backs' 'backward'
#  'backwards' 'backyard' 'bad' 'bag' 'bags' 'bailey' 'bairn' 'bairns'
#  'bake' 'baked' 'baker' 'baking' 'bald' 'ball' 'balloon' 'baloney'
#  'bananas' 'bananays' 'banbury' 'band' 'banjo' 'bank' 'banks' 'banky'
#  'baptismal' 'bar' 'barber' 'bards' 'bare' 'bark' 'barley' 'barn'
#  'barnyard' 'barrel' 'barrels' 'bars' 'baseball' 'baske' 'basket' 'bass'
#  'bat' 'bath' 'bathing' 'bathroom' 'bathtime' 'bathtub' 'batter' 'battle'
#  'bawdy' 'bay' 'be' 'beak' 'beaming' 'beams' 'beans' 'bear' 'bears' 'beat'
#  'beating' 'beau' 'beautiful' 'beauty' 'became' 'because' 'become' 'bed'
#  'beds' 'bee' 'beef' 'been' 'beep' 'beer' 'bees' 'beetle' 'before' 'began'
#  'beggar' 'beggars' 'begged' 'begotten' 'begun' 'behave' 'behind' 'behold'
#  'beige' 'being' 'believed' 'believer' 'bell' 'bella' 'bells' 'belong'
#  'belonged' 'below' 'belén' 'ben' 'bend' 'beneath' 'beneneys' 'berry'
#  'beside' 'best' 'bestest' 'bethlehem' 'better' 'betty' 'between'
#  'bicycle' 'bid' 'biddy' 'bide' 'big' 'bikes' 'bill' 'billy' 'bingo'
#  'bininis' 'bird' 'birds' 'birth' 'biscuit' 'biscuits' 'bit' 'bite'
#  'bites' 'bitsy' 'bitter' 'bitty' 'black' 'blackbird' 'blackbirds' 'blame'
#  'blast' 'blazing' 'bleating' 'bleed' 'bless' 'blessed' 'blessings' 'blew'
#  'blind' 'blissfully' 'blithe' 'blocked' 'blocks' 'blood' 'bloom'
#  'blooming' 'blossom' 'blotter' 'blow' 'blowin' 'blown' 'blows' 'blue'
#  'bluebird' 'blynken' 'bo' 'boat' 'bob' 'bobbin' 'bobby' 'bodie' 'bone'
#  'bones' 'bonnie' 'bonny' 'bononos' 'boo' 'book' 'boom' 'booma' 'boot'
#  'bopping' 'border' 'bore' 'born' 'borne' 'boss' 'boston' 'both' 'bother'
#  'botter' 'bottle' 'bottles' 'bottom' 'bottoms' 'bough' 'boughs' 'bought'
#  'bound' 'bow' 'bowl' 'bowle' 'box' 'boy' 'boyfriend' 'boys' 'branch'
#  'branches' 'brand' 'brass' 'bravely' 'bread' 'break' 'breaking' 'breaks'
#  'breeches' 'brick' 'bricks' 'bridge' 'bright' 'brightened' 'brightest'
#  'brightly' 'brilla' 'brilliant' 'bring' 'bringing' 'brings' 'britches'
#  'broke' 'broken' 'broom' 'broomstick' 'broth' 'brother' 'brought' 'brown'
#  'brush' 'bubble' 'bubbles' 'bucket' 'buckle' 'buckles' 'buckwheat'
#  'buffalo' 'bugs' 'build' 'built' 'bull' 'bullfrogs' 'bumble' 'bumblebee'
#  'bump' 'bumped' 'bun' 'bunch' 'bunches' 'bunnies' 'bunny' 'buns'
#  'bunting' 'bununus' 'burden' 'burial' 'buried' 'burn' 'burned' 'burning'
#  'burns' 'bury' 'bus' 'bush' 'bushel' 'but' 'butcher' 'butt' 'butter'
#  'butterfly' 'buttermilk' 'button' 'buttons' 'buy' 'by' 'bye' 'byeeee'
#  'cackle' 'cake' 'cali' 'california' 'call' 'called' 'calling' 'calls'
#  'calm' 'came' 'camel' 'camp' 'campo' 'can' 'candies' 'candle'
#  'candlestick' 'candy' 'cane' 'canna' 'cannot' 'canny' 'canoe' 'cantelon'
#  'cap' 'captain' 'car' 'caramba' 'care' 'cares' 'carol' 'carpet'
#  'carriage' 'carried' 'carry' 'cars' 'cart' 'cartoon' 'cast' 'castor'
#  'cat' 'catastrophe' 'catch' 'category' 'catherines' 'cats' 'caught'
#  'causa' 'cause' 'causing' 'cave' 'cease' 'ceiling' 'cellar' 'cemetery'
#  'cents' 'certain' 'cha' 'chains' 'chair' 'chamber' 'chance' 'chanced'
#  'chances' 'change' 'chariot' 'charming' 'chase' 'chased' 'chastening'
#  'chat' 'chatter' 'check' 'cheep' 'cheer' 'cheers' 'cheese' 'cherries'
#  'cherry' 'cheshire' 'chest' 'chew' 'chewed' 'chicago' 'chicka' 'chicken'
#  'chickens' 'chicks' 'chico' 'chief' 'chika' 'child' 'children' 'chill'
#  'chilling' 'chimney' 'chin' 'chirped' 'choirs' 'chop' 'chorus' 'christ'
#  'christened' 'christian' 'christmas' 'chubby' 'chuck' 'ciao' 'cider'
#  'cinders' 'circle' 'circles' 'circus' 'citizens' 'city' 'claire' 'clap'
#  'clapper' 'claps' 'clark' 'claus' 'clay' 'clean' 'cleaning' 'clear'
#  'clemens' 'clementine' 'clerk' 'clever' 'climb' 'climbed' 'climbing'
#  'clinging' 'clipper' 'clock' 'close' 'clothes' 'cloves' 'clown' 'cluck'
#  'coal' 'coaster' 'coat' 'coats' 'cobbler' 'cobweb' 'cock' 'cockle'
#  'cockroach' 'cocoa' 'coffin' 'cokey' 'cold' 'cole' 'color' 'colors'
#  'colour' 'colourful' 'colours' 'comb' 'combing' 'come' 'comes' 'comfort'
#  'comforts' 'comin' 'coming' 'commend' 'common' 'commotion' 'company'
#  'compare' 'concentration' 'confusing' 'congratulate' 'connected'
#  'connecti' 'consent' 'conspire' 'consultation' 'continental' 'continue'
#  'contraband' 'contrary' 'convincing' 'cooked' 'cookie' 'cool' 'cop'
#  'corn' 'corncob' 'corner' 'corners' 'cos' 'cottage' 'cough' 'could'
#  'couldn' 'counting' 'country' 'course' 'courtin' 'courting' 'covered'
#  'covers' 'cow' 'cows' 'crack' 'cracked' 'crackey' 'cradle' 'crawin'
#  'crawled' 'crazy' 'cream' 'created' 'creel' 'creeping' 'crew' 'cried'
#  'crimson' 'crocodiles' 'crook' 'crooked' 'cross' 'crow' 'crowed'
#  'crowing' 'crown' 'crumpled' 'crunchy' 'crust' 'cry' 'cryin' 'crying'
#  'crystal' 'cuckoo' 'cud' 'cup' 'cupboard' 'cupid' 'curbstone' 'curds'
#  'curl' 'curly' 'curse' 'curtains' 'curtsy' 'curve' 'curved' 'cushion'
#  'cut' 'cute' 'cuttin' 'cyclone' 'da' 'daddies' 'daddy' 'daffodils'
#  'daffy' 'dainties' 'dainty' 'daisies' 'daisy' 'dame' 'damp' 'dance'
#  'danced' 'dances' 'dancing' 'dandy' 'dang' 'dangers' 'dangle' 'danny'
#  'dapple' 'dare' 'dark' 'darling' 'dashing' 'daughter' 'daughters' 'daur'
#  'daw' 'dawn' 'dawned' 'day' 'dayes' 'days' 'de' 'dead' 'dealt' 'dear'
#  'death' 'deceive' 'deck' 'dee' 'deedle' 'deep' 'definitely' 'deity'
#  'delaware' 'delicate' 'delicious' 'delight' 'delightful' 'dell' 'delve'
#  'dem' 'dera' 'deri' 'derredor' 'derry' 'deserves' 'determined' 'devil'
#  'dew' 'dial' 'diamond' 'diamonds' 'dice' 'dickie' 'dickory' 'did'
#  'diddle' 'didn' 'die' 'died' 'different' 'dig' 'dilly' 'dimple' 'dims'
#  'dinah' 'ding' 'dink' 'dinky' 'dip' 'dirt' 'dirty' 'dis' 'disappear'
#  'disconnect' 'disconnected' 'disguise' 'dish' 'dishes' 'dishy' 'disna'
#  'ditches' 'ditty' 'dive' 'divey' 'divine' 'do' 'doats' 'dock' 'doctor'
#  'doctors' 'does' 'doesn' 'dog' 'doggie' 'dogs' 'doing' 'doll' 'dollar'
#  'dollars' 'dollies' 'dolly' 'don' 'done' 'dong' 'donkey' 'doo' 'doodle'
#  'doon' 'dooowwwwwwwn' 'door' 'dot' 'doth' 'double' 'dove' 'dover' 'doves'
#  'down' 'downstairs' 'downtown' 'dozy' 'dr' 'drag' 'drain' 'drank' 'draw'
#  'drawing' 'dream' 'dreamed' 'dreams' 'dreamt' 'drear' 'dress' 'dressed'
#  'dried' 'drifted' 'drifting' 'drink' 'drinking' 'drive' 'drives' 'droop'
#  'drop' 'dropped' 'drops' 'drown' 'drowned' 'drum' 'drummed' 'drummers'
#  'drumming' 'drunk' 'drury' 'dry' 'dub' 'dubby' 'duck' 'duckie'
#  'ducklings' 'ducks' 'duerme' 'duke' 'dumpling' 'dumpty' 'dust' 'dusty'
#  'dwell' 'dying' 'dynamite' 'each' 'eager' 'eagle' 'eaples' 'ear' 'early'
#  'ears' 'earth' 'ease' 'easy' 'eat' 'eater' 'eating' 'ee' 'eeena' 'eel'
#  'eena' 'eeny' 'eeper' 'egg' 'eggs' 'eight' 'eighteen' 'eighth' 'el'
#  'elbows' 'electric' 'element' 'elephant' 'elephants' 'eleven' 'eleventh'
#  'eli' 'ella' 'else' 'em' 'emmanuel' 'employ' 'empty' 'en' 'end' 'ending'
#  'england' 'enjoy' 'enough' 'enthrone' 'entre' 'er' 'erect' 'erected'
#  'error' 'es' 'eskimo' 'esparce' 'esparcen' 'espied' 'estate' 'estrella'
#  'están' 'ev' 'eva' 'eve' 'even' 'evening' 'ever' 'everlasting' 'evermore'
#  'every' 'everybody' 'everyone' 'everything' 'everywhere' 'eww' 'example'
#  'except' 'excepting' 'exchanged' 'excited' 'explained' 'extended'
#  'extremely' 'exultation' 'eye' 'eyes' 'eyght' 'ezekiel' 'fa' 'face'
#  'facing' 'fades' 'fading' 'fail' 'fair' 'fairing' 'fairy' 'faith'
#  'faithful' 'faithfully' 'fall' 'falling' 'falls' 'false' 'family' 'far'
#  'fare' 'farewell' 'farm' 'farmer' 'fast' 'fat' 'father' 'fathers'
#  'favorite' 'favourite' 'fawkes' 'fay' 'fe' 'fear' 'feared' 'feather'
#  'feathers' 'february' 'fed' 'feed' 'feeding' 'feel' 'feeling' 'feels'
#  'feet' 'felicidad' 'feliz' 'fell' 'fellow' 'felt' 'fence' 'fernando'
#  'fetch' 'few' 'fi' 'fiddle' 'fiddler' 'fiddlers' 'fiddles' 'fiddlestick'
#  'fiddlingstick' 'fiddly' 'fidler' 'fie' 'field' 'fields' 'fieles'
#  'fifteen' 'fifth' 'fifty' 'fighting' 'fill' 'filled' 'finale' 'finally'
#  'find' 'finds' 'fine' 'finest' 'finger' 'fingers' 'finish' 'fir' 'fire'
#  'first' 'fish' 'fisher' 'fishermen' 'fishes' 'fishie' 'fishies' 'fishin'
#  'fishy' 'fit' 'five' 'flag' 'flap' 'flashlights' 'flavor' 'flea' 'fled'
#  'fleece' 'fleetditch' 'fleeting' 'flesh' 'flew' 'flies' 'flinders' 'flip'
#  'flocks' 'floods' 'floor' 'flop' 'flori' 'flour' 'flow' 'flower'
#  'flowers' 'flowin' 'flowing' 'flu' 'flue' 'fluffy' 'flute' 'fly' 'flying'
#  'foam' 'fock' 'fol' 'foldy' 'folk' 'folks' 'follow' 'followed'
#  'following' 'fond' 'font' 'foo' 'food' 'foolin' 'foolish' 'foot' 'for'
#  'forehead' 'forest' 'forever' 'forevermore' 'forget' 'forgot' 'fork'
#  'forks' 'forlorn' 'fortune' 'foster' 'fought' 'found' 'four' 'fourteen'
#  'fourth' 'fox' 'frae' 'fragrant' 'free' 'freedom' 'french' 'fret'
#  'friday' 'fridays' 'friend' 'friends' 'frigerator' 'frightened'
#  'frightful' 'fro' 'frog' 'froggy' 'frogs' 'frolic' 'from' 'front'
#  'frosty' 'frown' 'froze' 'fruit' 'fruitcake' 'fruiterer' 'fuddled'
#  'fuddling' 'full' 'fun' 'funeral' 'funiculà' 'funiculì' 'funny' 'funtime'
#  'fuzzy' 'gad' 'gaily' 'gal' 'gallop' 'games' 'gander' 'garage' 'garden'
#  'garret' 'gate' 'gather' 'gato' 'gave' 'gay' 'gayest' 'gee' 'geese'
#  'gems' 'gentlemen' 'gently' 'georgie' 'get' 'gets' 'getten' 'getting'
#  'giddy' 'gie' 'gies' 'gift' 'gifts' 'gin' 'ginger' 'gingerbread' 'girl'
#  'girlie' 'girls' 'give' 'given' 'gives' 'giving' 'glass' 'gleam'
#  'gleaming' 'gleams' 'glee' 'glen' 'glistening' 'gloom' 'gloomy' 'glories'
#  'glorious' 'glory' 'gloster' 'gloucester' 'glow' 'glowering' 'glowing'
#  'glug' 'go' 'goat' 'gobbled' 'god' 'godhead' 'goes' 'goin' 'going' 'gold'
#  'golden' 'goldfish' 'golly' 'gone' 'goner' 'gonna' 'good' 'goodbye'
#  'goodbying' 'gooding' 'goodness' 'goodnight' 'gooey' 'goofy' 'goon'
#  'goooooon' 'goose' 'goosey' 'gosh' 'goslings' 'gospel' 'got' 'gotham'
#  'gotta' 'gown' 'gowns' 'grab' 'grace' 'grain' 'grand' 'grande'
#  'grandfather' 'grandma' 'grandmother' 'grandpa' 'grapes' 'grass'
#  'grasshopper' 'grateful' 'grave' 'gray' 'great' 'greatly' 'greedy'
#  'green' 'greet' 'grew' 'grey' 'grief' 'grieve' 'groat' 'grocers' 'ground'
#  'grow' 'grows' 'gruesome' 'grumble' 'grundy' 'guard' 'guess' 'guitar'
#  'guli' 'gum' 'gumdrops' 'gun' 'gunpowder' 'gust' 'gut' 'guy' 'ha' 'had'
#  'hadn' 'haggis' 'hail' 'hailed' 'hair' 'half' 'halfpenny' 'hall'
#  'hambone' 'hammer' 'hand' 'handle' 'hands' 'handy' 'hang' 'hanging'
#  'hanky' 'hap' 'happened' 'happens' 'happy' 'hard' 'hare' 'hark' 'harken'
#  'harm' 'harmonies' 'harness' 'harp' 'harvests' 'has' 'haste' 'hasten'
#  'hasty' 'hat' 'hate' 'hath' 'hatter' 'have' 'haven' 'having' 'haw'
#  'hawaii' 'hay' 'haystack' 'he' 'head' 'heads' 'healing' 'heals' 'healthy'
#  'hear' 'heard' 'hears' 'heart' 'hearted' 'hearts' 'heat' 'heav' 'heaved'
#  'heaven' 'heavenly' 'heavens' 'heavy' 'heedless' 'heel' 'heels' 'heigh'
#  'held' 'hello' 'help' 'hen' 'hens' 'her' 'herald' 'here' 'hero' 'heroes'
#  'herring' 'hesitations' 'hey' 'hickety' 'hickory' 'hid' 'hide' 'hiding'
#  'high' 'highest' 'hill' 'hillocks' 'hills' 'him' 'himself' 'hind' 'hip'
#  'hippity' 'hippo' 'hippopotamus' 'hippopotamuses' 'hippopotamuseses'
#  'hippos' 'his' 'hit' 'hitched' 'hive' 'hives' 'ho' 'hoes' 'hog' 'hokey'
#  'hold' 'hole' 'holiday' 'holla' 'holler' 'hollers' 'holloa' 'hollow'
#  'holly' 'holy' 'home' 'honey' 'honor' 'hoo' 'hootchy' 'hop' 'hope'
#  'hopes' 'hopping' 'horn' 'horner' 'horrid' 'horse' 'horses' 'horseshoe'
#  'hose' 'hosier' 'hoss' 'host' 'hosts' 'hot' 'hound' 'hour' 'hours'
#  'house' 'houses' 'how' 'howling' 'hubbard' 'huffin' 'hug' 'huh' 'humble'
#  'humming' 'hump' 'humps' 'humpty' 'hung' 'hungry' 'hunt' 'hunting'
#  'hurrah' 'hurray' 'hurry' 'hurt' 'hush' 'hushed' 'hymns' 'ice' 'idaho'
#  'iddy' 'ideal' 'if' 'ill' 'illuminates' 'in' 'incarnate' 'incense'
#  'indeed' 'indian' 'indians' 'infant' 'infest' 'injun' 'injuns' 'ink'
#  'insects' 'inside' 'inspected' 'instead' 'intent' 'into' 'intro' 'iowa'
#  'ip' 'iples' 'iron' 'is' 'island' 'isn' 'ite' 'its' 'itsy' 'iune' 'ives'
#  'ivy' 'jack' 'jacke' 'jacky' 'jacob' 'jags' 'jam' 'jane' 'janitor' 'jar'
#  'jay' 'jean' 'jenkins' 'jenny' 'jersey' 'jesus' 'jesús' 'jet' 'jig'
#  'jiggety' 'jill' 'jimmy' 'jingle' 'jingleheimer' 'jingling' 'jingo'
#  'jivey' 'joan' 'job' 'joe' 'jog' 'john' 'johnny' 'johnson' 'johny' 'join'
#  'joined' 'joke' 'jolly' 'jordan' 'jowler' 'joy' 'joyful' 'joyous'
#  'joyously' 'joys' 'juciest' 'judge' 'jug' 'juggle' 'juice' 'juicy' 'july'
#  'jumbled' 'jump' 'jumped' 'jumping' 'june' 'just' 'kangaroo' 'keel'
#  'keep' 'keeping' 'kenna' 'kept' 'kerplop' 'kettle' 'key' 'kick' 'kicked'
#  'kiddley' 'kids' 'kill' 'killed' 'kind' 'kindly' 'kinds' 'king' 'kingdom'
#  'kings' 'kiss' 'kissed' 'kisses' 'kissing' 'kitchen' 'kite' 'kits'
#  'kittens' 'kitty' 'kiwis' 'knack' 'knapsack' 'knave' 'knee' 'kneel'
#  'knees' 'knell' 'knew' 'knick' 'knife' 'knives' 'knock' 'knocked' 'knot'
#  'know' 'knows' 'kookaburra' 'kootchy' 'kumbaya' 'la' 'ladder' 'laddie'
#  'laden' 'ladies' 'ladle' 'lads' 'lady' 'ladybird' 'laid' 'lake' 'lamb'
#  'lambs' 'lamp' 'lamzy' 'land' 'lands' 'lane' 'lantern' 'lap' 'large'
#  'lark' 'lasses' 'lassie' 'last' 'late' 'later' 'laud' 'laugh' 'laughed'
#  'laughing' 'launched' 'lavender' 'law' 'lawyer' 'lay' 'laying' 'lays'
#  'lazy' 'lead' 'leader' 'lean' 'leap' 'leape' 'leaping' 'leapt' 'learned'
#  'learnt' 'leary' 'leave' 'leaves' 'leaving' 'led' 'lee' 'left' 'leg'
#  'legs' 'lemmons' 'lemon' 'lemonade' 'lend' 'less' 'lest' 'let' 'lets'
#  'letter' 'liberty' 'licked' 'lickin' 'liddle' 'lie' 'lies' 'life' 'lift'
#  'light' 'lightened' 'lighting' 'lights' 'lik' 'like' 'lily' 'limb' 'line'
#  'linen' 'ling' 'lingered' 'link' 'linnet' 'lion' 'lips' 'liquor' 'lisa'
#  'list' 'listen' 'listening' 'little' 'live' 'lived' 'livelong' 'lives'
#  'livin' 'living' 'liza' 'll' 'llama' 'lmnop' 'lo' 'load' 'loaded' 'loaf'
#  'loaves' 'lock' 'locket' 'locks' 'log' 'london' 'lonely' 'lonesome'
#  'long' 'longed' 'longer' 'longing' 'loo' 'looby' 'look' 'looked'
#  'looking' 'looks' 'loon' 'loose' 'lord' 'lords' 'los' 'lose' 'lost'
#  'lots' 'lou' 'loud' 'louisiana' 'lov' 'love' 'loved' 'lovely' 'lover'
#  'loves' 'loving' 'low' 'lowest' 'lowly' 'luck' 'lucky' 'lucy' 'lug'
#  'luke' 'lullaby' 'lunch' 'luz' 'ly' 'lydia' 'lying' 'lynn' 'lyrics'
#  'lyuli' 'macaroni' 'macdonald' 'macdougal' 'mack' 'made' 'madre' 'mae'
#  'magic' 'magical' 'maid' 'maiden' 'maids' 'mainly' 'maintain' 'mairzy'
#  'make' 'maker' 'makes' 'making' 'mama' 'mammy' 'man' 'manger' 'many'
#  'march' 'marched' 'marching' 'mares' 'margery' 'maria' 'marigold' 'mark'
#  'market' 'marriage' 'married' 'marry' 'marvelous' 'mary' 'maryland'
#  'massa' 'massage' 'master' 'match' 'matter' 'matthew' 'may' 'maybe' 'me'
#  'meadcup' 'meadow' 'meadows' 'meal' 'mean' 'measles' 'measure' 'meat'
#  'meatball' 'meatballs' 'medicine' 'mee' 'meena' 'meeny' 'meet'
#  'melancholic' 'melody' 'melons' 'melt' 'men' 'mend' 'ment' 'mention'
#  'meow' 'merchant' 'mercy' 'merrily' 'merry' 'message' 'met' 'mice'
#  'michael' 'micheal' 'mid' 'middle' 'might' 'mighty' 'mild' 'mile' 'miles'
#  'milk' 'milked' 'milking' 'milkshakes' 'milky' 'mill' 'miller' 'million'
#  'mina' 'mind' 'mine' 'minna' 'minute' 'miny' 'mirth' 'miss' 'missed'
#  'missing' 'mississip' 'missouri' 'mister' 'mistress' 'misty' 'mither'
#  'mittens' 'mitzi' 'mix' 'mmm' 'mmmm' 'mo' 'mockingbird' 'mockingbirds'
#  'modern' 'moe' 'mole' 'mom' 'moment' 'mommies' 'mommy' 'monday' 'money'
#  'monkey' 'monkeys' 'monstrous' 'monument' 'mony' 'moo' 'moon' 'moose'
#  'mop' 'mopping' 'moral' 'more' 'morena' 'morn' 'morning' 'mortar'
#  'mosquitoes' 'moss' 'most' 'mother' 'mothers' 'mountain' 'mountains'
#  'mourn' 'mourned' 'mourner' 'mouse' 'mousie' 'mouth' 'move' 'mowing'
#  'mrs' 'much' 'muffet' 'muffin' 'mulberry' 'mummy' 'mush' 'mushroom'
#  'music' 'musicians' 'must' 'my' 'myrrh' 'mysel' 'myself' 'nad' 'nail'
#  'nails' 'name' 'named' 'nan' 'nap' 'nations' 'native' 'nature' 'naughty'
#  'navidad' 'ne' 'near' 'nearly' 'neath' 'neatly' 'neck' 'need' 'needle'
#  'needs' 'neighbor' 'neighborhood' 'neither' 'nest' 'nets' 'never' 'new'
#  'newborn' 'newes' 'news' 'next' 'nice' 'nicely' 'nicht' 'nickel' 'niece'
#  'nifty' 'nigh' 'night' 'nights' 'nimble' 'nine' 'nineteen' 'ninety'
#  'ning' 'ninth' 'niñito' 'niño' 'no' 'nobody' 'noche' 'nod' 'nodded'
#  'noise' 'none' 'nonsense' 'noon' 'nor' 'north' 'northern' 'norwich'
#  'nory' 'nose' 'not' 'note' 'nothing' 'notions' 'nouember' 'nought'
#  'november' 'now' 'number' 'numerous' 'nurse' 'nut' 'nutmeg' 'nutty' 'oak'
#  'oaples' 'oats' 'oberon' 'occupied' 'ocean' 'of' 'off' 'offspring' 'oft'
#  'often' 'oh' 'ohio' 'oil' 'okay' 'oklahoma' 'ola' 'old' 'om' 'on' 'once'
#  'one' 'ones' 'only' 'onto' 'onything' 'oo' 'ooh' 'oooooooh' 'open'
#  'opened' 'operator' 'oppression' 'or' 'orange' 'oranges' 'orders'
#  'oregon' 'orient' 'origami' 'original' 'oscuridad' 'ote' 'other' 'others'
#  'ouch' 'our' 'ourselves' 'out' 'outside' 'oven' 'over' 'overboard'
#  'overhead' 'overthrow' 'ow' 'owl' 'own' 'ox' 'pa' 'pad' 'paddy'
#  'paddywhack' 'paid' 'pail' 'pain' 'painted' 'pair' 'pajamas' 'pal'
#  'palace' 'pall' 'pan' 'panky' 'panning' 'pans' 'pants' 'papa' 'paper'
#  'papers' 'paradise' 'park' 'parli' 'parlour' 'parrot' 'parsley' 'parson'
#  'part' 'parted' 'partner' 'partridge' 'pass' 'passed' 'passes' 'past'
#  'pastores' 'pat' 'patch' 'pate' 'path' 'pathways' 'patient' 'patiently'
#  'patter' 'paul' 'pauls' 'paused' 'pay' 'paz' 'peace' 'peach' 'peaches'
#  'pear' 'pears' 'peas' 'peasant' 'pease' 'peck' 'pecked' 'peckin'
#  'peekaboo' 'peep' 'peeped' 'pence' 'penguin' 'penicillin' 'penny'
#  'people' 'peppers' 'person' 'personal' 'peter' 'petticoat' 'phew' 'phone'
#  'phoned' 'pick' 'picked' 'pickety' 'pickin' 'pickled' 'picnic' 'pie'
#  'piece' 'pieces' 'pierce' 'pies' 'pig' 'piggy' 'pigs' 'pile' 'pill'
#  'pillow' 'pine' 'pineapple' 'pineapples' 'pining' 'pink' 'pipe' 'piper'
#  'pipers' 'pipes' 'piping' 'pirate' 'pisky' 'pistol' 'pitter' 'pity'
#  'pizza' 'place' 'placed' 'places' 'plain' 'plains' 'plan' 'plans' 'plate'
#  'plates' 'platter' 'play' 'played' 'playfellows' 'playing' 'playmate'
#  'plays' 'pleading' 'please' 'pleased' 'pleasure' 'plexus' 'plot' 'plough'
#  'plow' 'pluck' 'plug' 'plum' 'plus' 'pocket' 'pocketful' 'pockets'
#  'point' 'pointer' 'pokey' 'pole' 'polka' 'poll' 'polly' 'poly' 'pond'
#  'pony' 'poo' 'pool' 'poor' 'pop' 'popping' 'pops' 'popular' 'porgie'
#  'porridge' 'posies' 'positions' 'possessor' 'pot' 'potato' 'potatoes'
#  'pots' 'pound' 'pour' 'pouring' 'pow' 'powder' 'power' 'powley' 'pox'
#  'praise' 'prance' 'pray' 'prayed' 'prayers' 'preach' 'precious' 'prepare'
#  'present' 'president' 'pretend' 'prettier' 'prettiest' 'pretty' 'prick'
#  'prince' 'princess' 'proclaim' 'promise' 'promised' 'prospero' 'protect'
#  'proud' 'prove' 'providence' 'psalm' 'puddin' 'pudding' 'puddle' 'puff'
#  'pufferbellies' 'puffin' 'pull' 'pulled' 'pulling' 'pum' 'pumpkin'
#  'pumpkins' 'puppy' 'pure' 'purloined' 'purple' 'purr' 'purring' 'purse'
#  'push' 'pussy' 'pussycat' 'put' 'putting' 'quack' 'quaffing' 'quake'
#  'quarrel' 'quarrelled' 'quarter' 'quartered' 'que' 'queen' 'queer'
#  'quench' 'questions' 'quick' 'quiet' 'quills' 'quince' 'quite' 'rabbit'
#  'race' 'radiant' 'rafiq' 'rags' 'rah' 'rail' 'railroad' 'rain' 'rainbow'
#  'raindrops' 'rained' 'raining' 'raise' 'rake' 'ram' 'rambling' 'ran'
#  'rang' 'raps' 'rare' 'raspberry' 'rat' 'rate' 'rather' 'rattle' 'rattlin'
#  'rattling' 'raveling' 'rays' 're' 'reach' 'reached' 'read' 'reading'
#  'ready' 'really' 'reanimated' 'reason' 'receive' 'reconciled' 'recorded'
#  'red' 'redbreast' 'redeeming' 'refrain' 'refrigerator' 'regimental'
#  'reigns' 'rejoices' 'rejoicing' 'relieved' 'religion' 'remember'
#  'remembers' 'reminding' 'removing' 'repeat' 'repeats' 'reply' 'request'
#  'resound' 'rest' 'return' 'rey' 'rhinoceroseses' 'rhyme' 'rhymes'
#  'rhythm' 'ribbon' 'ribbons' 'ribs' 'rice' 'rich' 'ride' 'rider' 'riding'
#  'right' 'righteousness' 'rin' 'ring' 'ringing' 'ringman' 'rings' 'rins'
#  'rio' 'rise' 'risen' 'rising' 'rita' 'river' 'rivers' 'road' 'roam'
#  'roar' 'roaring' 'roast' 'rob' 'robbers' 'robin' 'rock' 'rocka' 'rocked'
#  'rocket' 'rocks' 'rod' 'rode' 'rogue' 'roldy' 'roll' 'rolled' 'roller'
#  'rollin' 'rolling' 'roly' 'roof' 'rook' 'room' 'roon' 'roost' 'rooster'
#  'rope' 'rosa' 'rose' 'rosebud' 'roses' 'rosy' 'round' 'rover' 'row'
#  'rowley' 'rowly' 'roy' 'rub' 'rubbed' 'rubber' 'ruffled' 'ruggin' 'rules'
#  'rum' 'rumblin' 'rumbling' 'run' 'running' 'runs' 'rush' 'ry' 'rye'
#  'sabbath' 'sack' 'sacks' 'sad' 'sadly' 'safe' 'safely' 'said' 'sail'
#  'sailed' 'sailing' 'sailor' 'sake' 'sal' 'salami' 'sale' 'sally'
#  'salvation' 'sam' 'same' 'san' 'sang' 'santa' 'santo' 'sat' 'satan'
#  'saturday' 'sauce' 'save' 'saved' 'savior' 'saviour' 'saw' 'say' 'saying'
#  'says' 'scare' 'scared' 'schmidt' 'school' 'scone' 'scooping' 'score'
#  'scouts' 'scratching' 'scrub' 'scrumptious' 'sea' 'seam' 'search' 'seas'
#  'seashells' 'seashore' 'season' 'seat' 'second' 'see' 'seed' 'seek'
#  'seem' 'seemed' 'seems' 'seen' 'sees' 'self' 'sell' 'sells' 'sempstress'
#  'send' 'senor' 'sent' 'september' 'serenely' 'servant' 'serve' 'served'
#  'set' 'seven' 'seventeen' 'seventh' 'sew' 'sewed' 'sh' 'shadow'
#  'shadowed' 'shadows' 'shafto' 'shake' 'shakes' 'shaking' 'shall' 'shalt'
#  'shame' 'shampoo' 'shapes' 'share' 'sharing' 'shark' 'sharp' 'shaven'
#  'she' 'shed' 'sheep' 'shelf' 'shell' 'shells' 'shenandoah' 'shepherd'
#  'shepherdess' 'shepherds' 'shifta' 'shimmy' 'shin' 'shine' 'shines'
#  'shining' 'ship' 'shivers' 'shoe' 'shoes' 'shone' 'shoo' 'shook'
#  'shooting' 'shop' 'shorn' 'short' 'shorter' 'shot' 'shotgun' 'should'
#  'shoulder' 'shoulders' 'shout' 'shouting' 'shove' 'show' 'shower' 'shows'
#  'shrieking' 'shroud' 'shut' 'siana' 'sick' 'side' 'sierra' 'sigh'
#  'sighed' 'sighing' 'sight' 'sights' 'signs' 'silent' 'silk' 'silking'
#  'silly' 'silver' 'simply' 'sin' 'since' 'sing' 'singin' 'singing'
#  'single' 'sings' 'sinners' 'sins' 'sip' 'sipped' 'sir' 'sister' 'sisters'
#  'sit' 'sits' 'sittin' 'sitting' 'six' 'sixpence' 'sixteen' 'sixth'
#  'sixty' 'size' 'sized' 'sizes' 'skidamarink' 'skies' 'skill' 'skin'
#  'skip' 'skipped' 'skirlin' 'sky' 'skylarks' 'slapping' 'slated'
#  'slaughtered' 'slave' 'sleep' 'sleepin' 'sleeping' 'sleepy' 'sleigh'
#  'sleighing' 'slice' 'slide' 'slight' 'slip' 'slipped' 'slow' 'slowly'
#  'slut' 'sly' 'small' 'smell' 'smile' 'smiled' 'smoke' 'smoked' 'smokey'
#  'smoking' 'snack' 'snacks' 'snails' 'snake' 'snares' 'sneeze' 'sneezed'
#  'snips' 'snoring' 'snow' 'snowflakes' 'snowman' 'snowmen' 'snows' 'so'
#  'soap' 'sobbing' 'sobre' 'sock' 'socks' 'soda' 'soft' 'softball' 'softly'
#  'soiled' 'solar' 'sold' 'soldier' 'solomon' 'some' 'somebody' 'someone'
#  'something' 'sometimes' 'son' 'song' 'songs' 'sons' 'soon' 'soothes'
#  'sore' 'sorrow' 'sorrows' 'sorry' 'soul' 'souls' 'sound' 'sounding'
#  'soundly' 'sounds' 'south' 'sowing' 'sows' 'spaghetti' 'spain' 'spandy'
#  'spark' 'sparkle' 'sparrow' 'sparrows' 'spear' 'special' 'speckled'
#  'sped' 'speldert' 'spell' 'spend' 'spent' 'spice' 'spider' 'spied' 'spin'
#  'spine' 'spinning' 'spirits' 'spite' 'splash' 'splish' 'spoiled'
#  'spoiling' 'spoke' 'sponge' 'spoon' 'sport' 'spouse' 'spout' 'sprat'
#  'spread' 'spreading' 'spree' 'spring' 'sprung' 'spunky' 'spurs' 'spy'
#  'square' 'squash' 'squashing' 'squeals' 'squeeze' 'squirm' 'squirt'
#  'squishing' 'ssss' 'st' 'stair' 'stairs' 'stallion' 'stamping' 'stamps'
#  'stand' 'standin' 'standing' 'stands' 'star' 'stare' 'stares' 'starry'
#  'stars' 'start' 'started' 'starting' 'station' 'stay' 'stayed' 'steady'
#  'steal' 'steam' 'steamboat' 'steamed' 'steel' 'steeple' 'stella' 'step'
#  'stepney' 'stepped' 'stick' 'sticks' 'stiffen' 'stile' 'still' 'stingo'
#  'stings' 'stitch' 'stockings' 'stole' 'stolen' 'stomp' 'stony' 'stood'
#  'stoorie' 'stop' 'stopped' 'stopping' 'stops' 'storm' 'story' 'stousie'
#  'stout' 'straight' 'strange' 'stranger' 'straw' 'strawberries' 'stray'
#  'stream' 'street' 'streets' 'strength' 'stretch' 'strike' 'stringy'
#  'stronger' 'struck' 'strummin' 'stubbed' 'stuck' 'stumpie' 'stung'
#  'style' 'stylish' 'su' 'such' 'suck' 'suds' 'sugar' 'suitable' 'sukey'
#  'summer' 'summertime' 'sun' 'sunburned' 'sunday' 'sunshine' 'sup'
#  'supper' 'supping' 'suppose' 'sure' 'surely' 'surprise' 'surveyed'
#  'susanna' 'susie' 'susyanna' 'swans' 'swarm' 'swatter' 'sweep' 'sweeper'
#  'sweet' 'sweeter' 'sweetest' 'sweetheart' 'sweetly' 'swim' 'swimmin'
#  'swimming' 'swine' 'swing' 'swingin' 'swish' 'switch' 'switched' 'sword'
#  'swore' 'sólo' 'ta' 'table' 'tack' 'tail' 'tailor' 'tails' 'take' 'takes'
#  'taking' 'tale' 'talk' 'talks' 'tall' 'tallman' 'también' 'tambourine'
#  'tannenbaum' 'tap' 'tapping' 'tar' 'tarry' 'tarts' 'tasket' 'taste'
#  'tasteful' 'tasty' 'tat' 'tattered' 'taught' 'tavern' 'tea' 'teacher'
#  'team' 'teapot' 'tear' 'tears' 'tease' 'teddy' 'teeth' 'telegraph' 'tell'
#  'telling' 'tells' 'temperature' 'ten' 'tended' 'tender' 'tenna'
#  'tennessee' 'tenth' 'texas' 'than' 'thank' 'thanked' 'thanks'
#  'thanksgiving' 'that' 'the' 'thee' 'their' 'them' 'then' 'there'
#  'therefore' 'these' 'they' 'thick' 'thief' 'thigh' 'thin' 'thing'
#  'things' 'think' 'thinking' 'third' 'thirst' 'thirteen' 'thirty' 'this'
#  'thistle' 'thorns' 'those' 'thou' 'though' 'thought' 'thousand' 'thread'
#  'threads' 'three' 'thresh' 'threw' 'thrill' 'thrilling' 'throat'
#  'through' 'throughout' 'throw' 'throwing' 'thru' 'thrums' 'thrush'
#  'thumb' 'thumbkin' 'thumbs' 'thump' 'thumpity' 'thunder' 'thursday'
#  'thursdays' 'thus' 'thy' 'tickle' 'ticklish' 'tide' 'tie' 'tied' 'ties'
#  'tiger' 'tight' 'til' 'tildy' 'till' 'tilly' 'tim' 'time' 'times' 'ting'
#  'tinker' 'tinkertoy' 'tinkle' 'tiny' 'tip' 'tired' 'tirlin' 'tis'
#  'tishoo' 'tisket' 'tittlemouse' 'to' 'toast' 'today' 'toddled' 'todo'
#  'toe' 'toes' 'together' 'toils' 'told' 'toldy' 'toll' 'tom' 'tomato'
#  'tommy' 'tomorrow' 'tongue' 'tonight' 'too' 'toodle' 'took' 'toon' 'toot'
#  'tooty' 'top' 'topmost' 'torment' 'torn' 'toss' 'tossed' 'totally'
#  'touch' 'toward' 'towel' 'town' 'toy' 'toys' 'track' 'traffic' 'train'
#  'traveller' 'treacle' 'tread' 'treading' 'treason' 'treasure' 'treasures'
#  'treat' 'tree' 'trees' 'treetops' 'trembled' 'trials' 'tricks' 'tried'
#  'trip' 'tripe' 'triple' 'triumph' 'triumphant' 'trod' 'trot' 'troubles'
#  'troul' 'trousers' 'trowel' 'truck' 'truckin' 'true' 'truly' 'trundle'
#  'trust' 'trusted' 'truth' 'try' 'trying' 'tub' 'tubby' 'tuck' 'tucker'
#  'tuesday' 'tuffet' 'tugging' 'tumbled' 'tumblin' 'tumbling' 'tummy'
#  'tune' 'tuppenny' 'turkey' 'turn' 'turned' 'turnips' 'turns' 'turtle'
#  'turtledoves' 'tv' 'twas' 'tweedledee' 'tweedledum' 'twelfth' 'twelve'
#  'twentie' 'twenty' 'twice' 'twinkle' 'twinkling' 'twist' 'two' 'uh' 'uk'
#  'una' 'unafraid' 'unawares' 'unborn' 'uncle' 'under' 'underneath'
#  'understood' 'undertaker' 'unicorn' 'unique' 'unknown' 'unprotected'
#  'until' 'up' 'upon' 'upset' 'upstairs' 'us' 'usa' 'use' 'used' 'ute'
#  'uuples' 'val' 'valley' 'vanish' 'vanished' 'vans' 've' 'vegetarian'
#  'veiled' 'velan' 'velando' 'velvet' 'verra' 'verse' 'version' 'versions'
#  'very' 'vessel' 'victory' 'video' 'view' 'viewed' 'village' 'violets'
#  'virgin' 'visit' 'voice' 'voices' 'vow' 'vowed' 'vroom' 'waddle' 'waggle'
#  'waggly' 'wagon' 'wah' 'waistcoat' 'wait' 'waited' 'waiting' 'wake'
#  'wakeful' 'waking' 'walk' 'walked' 'walker' 'walking' 'walks' 'wall'
#  'wamblin' 'wander' 'wandered' 'wandering' 'wanna' 'want' 'wanted' 'wants'
#  'warm' 'warmer' 'warming' 'warms' 'wart' 'was' 'wash' 'washcloth'
#  'washed' 'washington' 'wasn' 'watch' 'watched' 'watches' 'watching'
#  'water' 'watered' 'watermelon' 'watermelons' 'waters' 'waukenin'
#  'waukrife' 'wave' 'waved' 'waves' 'wavin' 'wavy' 'wax' 'way' 'we'
#  'weaknesses' 'wealthy' 'wean' 'weans' 'wear' 'wearing' 'wearit' 'weary'
#  'weasel' 'weather' 'weaving' 'wed' 'wedding' 'wednesday' 'wee' 'weeds'
#  'weel' 'weep' 'weeper' 'weighed' 'weighs' 'welcome' 'well' 'went' 'were'
#  'west' 'wet' 'whale' 'what' 'wheels' 'when' 'whenever' 'where' 'wherever'
#  'whey' 'which' 'while' 'whilst' 'whip' 'whipped' 'whiskers' 'whistle'
#  'white' 'whitechapple' 'whither' 'who' 'whoa' 'whole' 'whom' 'whoop'
#  'whooping' 'whoops' 'whose' 'why' 'wi' 'wide' 'wife' 'wig' 'will'
#  'willie' 'wills' 'willy' 'wind' 'window' 'winds' 'wine' 'wing' 'wings'
#  'wink' 'winked' 'winkie' 'winkin' 'winter' 'wintertime' 'wiped' 'wipers'
#  'wire' 'wiscon' 'wise' 'wish' 'wished' 'wishes' 'witches' 'with' 'within'
#  'without' 'wives' 'woah' 'wobble' 'woe' 'woke' 'wolly' 'woman' 'womb'
#  'won' 'wonder' 'wonderful' 'wonderland' 'wonders' 'wondrous' 'wont'
#  'wood' 'woodchuck' 'wooden' 'woods' 'wool' 'word' 'words' 'wore' 'work'
#  'worked' 'workin' 'working' 'works' 'world' 'worm' 'worried' 'worry'
#  'worse' 'worth' 'would' 'wouldn' 'wounded' 'wounds' 'wow' 'wrap' 'wren'
#  'wretch' 'wriggling' 'write' 'wrong' 'wrote' 'wunna' 'wuzzy' 'wynken'
#  'ya' 'yankee' 'yard' 'ye' 'yea' 'yeah' 'yeahhhhhh' 'year' 'years' 'yee'
#  'yellow' 'yes' 'yet' 'yield' 'yon' 'yonder' 'york' 'you' 'young' 'your'
#  'yours' 'yourself' 'youth' 'yum' 'yummy' 'zany' 'zee' 'zero' 'zoo' 'zoom']

# %% [markdown]
# To see the names of all of our nursery rhymes and their indexes in the documents lists we can run the following code. This will give us a [dictionary](https://www.w3schools.com/python/python_dictionaries.asp), a very useful data structure in Python, that we can use to find the index value of each nursery rhyme, using he nursery rhyme as our **keys**.

# %%
# This line of code is originally from: https://stackoverflow.com/a/36460020
document_labels_dict = {k: v for v, k in enumerate(document_labels)}
document_labels_dict
# Out:
# {'five-little-ducks': 0,
#  'old-mother-hubbard': 1,
#  'hey-diddle-diddle': 2,
#  'i-love-little-pussy': 3,
#  'skip-to-my-loo': 4,
#  'jack-a-nory': 5,
#  'baby-shark-dance': 6,
#  'deck-the-halls': 7,
#  'what-child-is-this': 8,
#  'to-bed-to-bed': 9,
#  'do-you-hear-what-i-hear': 10,
#  'hes-got-the-whole-world-in-his-hands': 11,
#  'head-shoulders-knees-and-toes': 12,
#  'solomon-grundy': 13,
#  'johny-johny-yes-papa': 14,
#  'see-saw-margery-daw': 15,
#  'jingle-bells': 16,
#  'hickory-dickory-dock': 17,
#  'autumn-leaves-are-falling-down': 18,
#  'a-sailor-went-to-sea-sea-sea': 19,
#  'mondays-child': 20,
#  'pease-porridge-hot': 21,
#  'bella-ciao': 22,
#  'way-up-high-in-the-apple-tree': 23,
#  'aiken-drum': 24,
#  'feliz-navidad': 25,
#  'lazy-mary': 26,
#  'draw-a-pail-of-water': 27,
#  'swing-low-sweet-chariot': 28,
#  'here-we-go-looby-loo': 29,
#  'going-on-a-bear-hunt': 30,
#  'cobbler-cobbler-mend-my-shoe': 31,
#  'a-tisket-a-tasket': 32,
#  'turkey-in-the-straw': 33,
#  'the-grand-old-duke-of-york': 34,
#  'sur-le-pont-davignon': 35,
#  'danny-boy': 36,
#  'did-you-ever-see-a-lassie': 37,
#  'bobby-shafto': 38,
#  'bubble-gum-bubble-gum-in-a-dish': 39,
#  'what-are-little-boys-made-of': 40,
#  'concentration-64': 41,
#  'miss-mary-mack': 42,
#  'jack-and-jill': 43,
#  'little-polly-flinders': 44,
#  'down-down-baby': 45,
#  'miss-polly-had-a-dolly': 46,
#  'brahms-lullaby': 47,
#  'cleanup-song': 48,
#  'o-tannenbaum': 49,
#  'sally-goes-round-the-sun': 50,
#  'baby-bumblebee': 51,
#  'eeny-meeny-miny-moe': 52,
#  'little-tommy-tucker': 53,
#  'three-wise-men-of-gotham': 54,
#  'beans-beans-the-magical-fruit': 55,
#  'down-by-the-bay': 56,
#  'hickety-pickety-my-black-hen': 57,
#  'one-for-sorrow': 58,
#  'rubber-duckie-song': 59,
#  'twelve-days-of-christmas': 60,
#  'teddy-bears-picnic': 61,
#  'go-tell-it-on-the-mountain': 62,
#  'where-are-you-going-my-pretty-maid': 63,
#  'ive-been-working-on-the-railroad': 64,
#  'guess-what-chicken-butt': 65,
#  'the-ants-go-marching': 66,
#  'six-little-mice': 67,
#  'to-market-to-market': 68,
#  'playmate-come-out-and-play-with-me': 69,
#  'im-a-little-teapot': 70,
#  'roses-are-red': 71,
#  'rub-a-dub-dub': 72,
#  'hark-the-herald-angels-sing': 73,
#  'the-other-day-i-met-a-bear': 74,
#  'little-liza-jane': 75,
#  'cielito-lindo': 76,
#  'de-colores': 77,
#  'the-fruits-song': 78,
#  'the-farmer-in-the-dell': 79,
#  'london-bridge-is-falling-down': 80,
#  'one-little-finger': 81,
#  'oh-dear-what-can-the-matter-be': 82,
#  'here-we-go-round-the-mulberry-bush': 83,
#  'how-much-wood-would-a-woodchuck-chuck': 84,
#  'lucy-locket': 85,
#  'boom-boom-aint-it-great-to-be-crazy': 86,
#  'o-christmas-tree': 87,
#  'the-lion-and-the-unicorn': 88,
#  'who-stole-the-cookie-from-the-cookie-jar': 89,
#  'i-had-a-little-turtle': 90,
#  'ladybird-ladybird': 91,
#  'little-tommy-tittlemouse': 92,
#  'row-row-row-your-boat': 93,
#  'cuckoo-cherry-tree': 94,
#  'pussy-cat-pussy-cat': 95,
#  'this-is-the-house-that-jack-built': 96,
#  'there-was-a-jolly-miller-once': 97,
#  'diddle-dumpling': 98,
#  'hickety-pickety-bumblebee': 99,
#  'curly-locks': 100,
#  'if-youre-happy-and-you-know-it': 101,
#  'oranges-and-lemons': 102,
#  'this-old-man': 103,
#  'the-lady-with-the-alligator-purse': 104,
#  'i-want-a-hippopotamus-for-christmas': 105,
#  'on-top-of-old-smokey': 106,
#  'little-jack-horner': 107,
#  'i-can-sing-a-rainbow': 108,
#  'oats-peas-beans-and-barley-grow': 109,
#  'one-potato-two-potatoes': 110,
#  'joy-to-the-world': 111,
#  'old-king-cole': 112,
#  'ten-in-the-bed': 113,
#  'winter-wonderland': 114,
#  'down-by-the-station': 115,
#  'teddy-bear-teddy-bear-turn-around': 116,
#  'two-little-dickie-birds': 117,
#  'humpty-dumpty': 118,
#  'pat-a-cake-pat-a-cake-bakers-man': 119,
#  'cock-a-doodle-doo': 120,
#  'the-wheels-on-the-bus': 121,
#  'on-top-of-spaghetti': 122,
#  'the-happy-wanderer': 123,
#  'dem-bones': 124,
#  'i-had-a-little-nut-tree': 125,
#  'billy-boy': 126,
#  'mary-mary-quite-contrary': 127,
#  'five-little-monkeys': 128,
#  'do-your-ears-hang-low': 129,
#  'red-river-valley': 130,
#  'i-see-the-moon-and-the-moon-sees-me': 131,
#  'wee-willie-winkie': 132,
#  'day-is-done-gone-the-sun': 133,
#  'polly-wolly-doodle': 134,
#  'and-the-green-grass-grows-all-around': 135,
#  'frosty-the-snowman': 136,
#  'she-sells-seashells': 137,
#  'matthew-mark-luke-and-john': 138,
#  'thirty-days-hath-september': 139,
#  'mary-had-a-little-lamb': 140,
#  'bye-baby-bunting': 141,
#  'silent-night': 142,
#  'how-many-days-has-my-baby-to-play': 143,
#  'yankee-doodle': 144,
#  'who-killed-cock-robi': 145,
#  'funiculi-funicula': 146,
#  'make-new-friends-but-keep-the-old': 147,
#  'tweedledum-and-tweedledee': 148,
#  'one-two-three-four-five': 149,
#  'my-bonnie-lies-over-the-ocean': 150,
#  'hokey-cokey': 151,
#  'cock-robin': 152,
#  'down-by-the-banks-of-the-hanky-panky': 153,
#  'how-many-miles-to-babylon': 154,
#  'are-you-sleeping-brother-john': 155,
#  'how-much-is-that-doggie-in-the-window': 156,
#  'eeper-weeper': 157,
#  'let-it-snow': 158,
#  'little-drummer-boy': 159,
#  'all-i-want-for-christmas-is-my-two-front-teeth': 160,
#  'little-bo-peep': 161,
#  'sleeping-bunnies': 162,
#  'the-alphabet-song': 163,
#  'if-all-the-world-was-apple-pie': 164,
#  'one-two-buckle-my-shoe': 165,
#  'theres-a-hole-in-the-bottom-of-the-sea': 166,
#  'shoo-fly-dont-bother-me': 167,
#  'the-muffin-man': 168,
#  'yellow-rose-of-texas': 169,
#  'hark-hark-the-dogs-do-bark': 170,
#  'ip-dip': 171,
#  'itsy-bitsy-spider': 172,
#  'a-was-an-apple-pie': 173,
#  'what-did-delaware': 174,
#  'goosey-goosey-gander': 175,
#  'stella-ella-ola': 176,
#  'the-north-wind-doth-blow': 177,
#  'lemonade-crunchy-ice': 178,
#  'once-i-saw-a-little-bird': 179,
#  'dance-to-your-daddy': 180,
#  'little-bunny-foo-foo': 181,
#  'ding-dong-bell': 182,
#  'over-the-river-and-through-the-woods': 183,
#  'old-macdonald-had-a-farm': 184,
#  'john-jacob-jingleheimer-schmidt': 185,
#  'kookaburra-song': 186,
#  'here-are-the-ladys-knives-and-forks': 187,
#  'old-joe-clark': 188,
#  'little-poll-parrot': 189,
#  'peter-piper': 190,
#  'round-and-round-the-garden': 191,
#  'kumbaya': 192,
#  'la-cucaracha': 193,
#  'alouette': 194,
#  'the-queen-of-hearts': 195,
#  'senor-don-gato': 196,
#  'wynken-blynken-and-nod': 197,
#  'lavenders-blue': 198,
#  'christmas-is-coming': 199,
#  'daffy-down-dilly': 200,
#  'man-in-the-moon-came-down-too-soon': 201,
#  'las-mananitas': 202,
#  'skidamarink': 203,
#  'apples-and-bananas': 204,
#  'alice-the-camel': 205,
#  'frog-went-a-courtin': 206,
#  'kalinka': 207,
#  'gingerbread-man': 208,
#  'rock-a-bye-baby': 209,
#  'where-is-thumbkin': 210,
#  'five-little-snowmen': 211,
#  'oh-where-oh-where-has-my-little-dog-gone': 212,
#  'noche-de-paz': 213,
#  'little-robin-redbreast': 214,
#  'girls-and-boys-come-out-to-play': 215,
#  'as-i-was-going-to-st-ives': 216,
#  'alle-meine-entchen': 217,
#  'rain-rain-go-away': 218,
#  'betty-botter': 219,
#  'amazing-grace': 220,
#  'little-miss-muffet': 221,
#  'shell-be-coming-round-the-mountain': 222,
#  'pop-goes-the-weasel': 223,
#  'trot-trot-to-boston': 224,
#  'oh-susanna': 225,
#  'for-want-of-a-nail': 226,
#  'old-mother-leary': 227,
#  'tinker-tailor': 228,
#  'finger-family': 229,
#  'star-light-star-bright': 230,
#  'the-cat-came-back': 231,
#  'o-holy-night': 232,
#  'ah-vous-dirai-je-maman': 233,
#  'there-was-a-little-girl': 234,
#  'the-fifth-of-november': 235,
#  'sing-a-song-of-sixpence': 236,
#  'there-was-a-crooked-man': 237,
#  'fuzzy-wuzzy-was-a-bear': 238,
#  'frere-jacques': 239,
#  'lift-every-voice-and-sing': 240,
#  'if-all-the-seas-were-one-sea': 241,
#  'zoom-zoom-were-going-to-the-moon': 242,
#  'ten-little-indians': 243,
#  'doctor-foster': 244,
#  'see-you-later-alligator': 245,
#  'hurry-hurry-drive-the-fire-truck': 246,
#  'jenny-jenkins': 247,
#  'if-wishes-were-horses': 248,
#  'jack-sprat': 249,
#  'tom-tom-the-pipers-son': 250,
#  'baa-baa-black-sheep': 251,
#  'miss-susie-had-a-steamboat': 252,
#  'polly-put-the-kettle-on': 253,
#  'clap-hands': 254,
#  'the-sharing-song': 255,
#  'this-little-piggy': 256,
#  'ride-a-cock-horse-to-banbury-cross': 257,
#  'if-all-the-world-were-paper': 258,
#  'ring-a-ring-o-roses': 259,
#  'o-come-all-ye-faithful': 260,
#  'i-hear-thunder': 261,
#  'ten-green-bottles': 262,
#  'sick-song': 263,
#  'hush-little-baby': 264,
#  'oh-shenandoah': 265,
#  'little-sally-walker': 266,
#  'bingo-song': 267,
#  'early-to-bed': 268,
#  'three-little-kittens': 269,
#  'hot-cross-buns': 270,
#  'its-raining-its-pouring': 271,
#  'cackle-cackle-mother-goose': 272,
#  'boom-chicka-boom': 273,
#  'mares-eat-oats': 274,
#  'tooty-ta': 275,
#  'five-little-pumpkins': 276,
#  'daisy-bell': 277,
#  'a-wise-old-owl': 278,
#  'jimmy-crack-corn': 279,
#  'this-little-light-of-mine': 280,
#  'georgie-porgie': 281,
#  'willy-boy-willy-boy-where-are-you-going': 282,
#  'peekaboo': 283,
#  'there-was-an-old-woman-who-lived-in-a-shoe': 284,
#  'a-ram-sam-sam': 285,
#  'oh-mr-sun': 286,
#  'peter-peter-pumpkin-eater': 287,
#  'apple-pie-abc': 288,
#  'jack-be-nimble': 289,
#  'little-boy-blue': 290,
#  'wind-the-bobbin-up': 291,
#  'if-all-the-raindrops': 292,
#  'splash-splash': 293,
#  'five-little-speckled-frogs': 294,
#  'here-i-am-little-jumping-joan': 295,
#  'twinkle-twinkle-little-star': 296,
#  'handy-spandy-jack-a-dandy': 297}

# %% [markdown]
# Now we can look at just the word counts for the first nursery rhyme (0), as we can see they are still mostly 0 entries.

# %%
single_row_df = bow_df.iloc[0]
single_row_df
# Out:
# 15      0
# 1784    0
# 1812    0
# 3x      0
# 4th     0
#        ..
# zany    0
# zee     0
# zero    0
# zoo     0
# zoom    0
# Name: five-little-ducks, Length: 3416, dtype: int64

# %% [markdown]
# To get a better sense of the contents of the rhymes, lets get rid of all of the counts that are 0. The simple way to do this is to replace them with the special variable `None` and then to remove of none-entries.
#
# We can now get a much better sense of what our nuersery rhyme is about:

# %%
single_row_df = single_row_df.replace(0,None)
single_row_df = single_row_df.dropna()
single_row_df
# Out:
# away         3
# back         4
# but          3
# came         4
# counting     1
# day          3
# down         1
# duck         4
# ducks        6
# far          3
# five         2
# four         2
# hills        3
# little       6
# mother       4
# no           1
# one          3
# only         2
# out          3
# over         3
# quack       12
# repeat       1
# sad          1
# said         3
# the          3
# three        1
# to           1
# went         3
# Name: five-little-ducks, dtype: object

# %% [markdown]
# Now we are going to use our bag of words representation to do build a simple search engine based on key words. We will use the [dot product](https://numpy.org/doc/stable/reference/generated/numpy.dot.html) to compare our poems with a representation of an individual word to see their similiarity.
#
# **Don't worry if you don't understand this code** for now. Linear algebra will be covered in more detail later in the term in the [STEM for Creatives](https://moodle.arts.ac.uk/course/view.php?id=79539) unit, and dictionaries and lambda functions will be also be covered later in STEM for Creative and Introduction to Data Science.

# %%
def retrieve_documents_by_keyword(document_labels, bow_matrix, vectorizer, keyword):
    keyword_bow = vectorizer.transform([keyword])
    
    # Use the dot product to find nursery rhymes that have our keyword 
    dot_product = np.dot(bow_matrix, keyword_bow.T).toarray().flatten()

    # Create a dictionary to store document names and their relevance scores then sort it
    document_relevance = {doc: score for doc, score in zip(document_labels, dot_product) if score > 0}
    sorted_documents = sorted(document_relevance.items(), key=lambda x: x[1], reverse=True)

    return sorted_documents

# %% [markdown]
# We can now use our function to find the most relevant nursery rhymes based on a key word, or multiple keywords. The document score tells us the relevance of each rhyme. Using our simple representation of text we have made a simple search engine!
#
# Try a few different keywords to see what rhymes you can retrieve.
#
# <a id='search'></a>

# %%
keyword = "sea"

# Retrieve documents containing the keyword
document_scores = retrieve_documents_by_keyword(document_labels, bag_of_words, vectorizer, keyword)
document_scores
# Out:
# [('theres-a-hole-in-the-bottom-of-the-sea', 24),
#  ('a-sailor-went-to-sea-sea-sea', 12),
#  ('wynken-blynken-and-nod', 5),
#  ('my-bonnie-lies-over-the-ocean', 3),
#  ('if-all-the-seas-were-one-sea', 3),
#  ('do-you-hear-what-i-hear', 2),
#  ('rub-a-dub-dub', 2),
#  ('bobby-shafto', 1),
#  ('three-wise-men-of-gotham', 1),
#  ('i-had-a-little-nut-tree', 1),
#  ('i-see-the-moon-and-the-moon-sees-me', 1),
#  ('make-new-friends-but-keep-the-old', 1),
#  ('if-all-the-world-was-apple-pie', 1),
#  ('lift-every-voice-and-sing', 1),
#  ('if-all-the-world-were-paper', 1)]

# %% [markdown]
# # Tasks
#
# **Task 1:** Try some different keywords in the [search tool](#search), then look at the rhymes to see if you search results look reasonable.
#
# **Task 2:** Go to the cell that defines the [stop words](#stop-words) and add start adding more stop words to the set. Do this **without** using a preset library of English stop words. Try looking at the list of [all of the words](#all-words) in the dataset for examples of words that aren't specific to the rhymes.
#
# **Task 3a:** Go to the cell that defines the [stemmer](#stemmer) and uncomment the first rule. The run all of the cells after that. See how that changes the number of words that are in our dataset.
#
# **Task 3b:** Now try to define your own rules for the [stemmer](#stemmer). Try looking at the list of [all of the words](#all-words) in the dataset for words that are similiar but have different endings, that should give you some clues for what rules of letters to remove that you can add to the stemmer code.
#
# **Task 4:** Once you have build your stemmer and stop words database, go back to the [search tool](#search), are you still getting the results you got earlier. Has the effectiveness of the search improved?
#
# **Bonus task** If you have completed all of the tasks and want a further challenge, can you replace the stemmer with the [NLTK WordNet lemmatizer](https://pythonprogramming.net/lemmatizing-nltk-tutorial/)? How does that effect the search function compared to the stemmer?
